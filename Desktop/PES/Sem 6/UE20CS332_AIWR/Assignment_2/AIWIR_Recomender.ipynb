# %%
import pandas as pd

# %%
df = pd.read_csv("spotify_millsongdata.csv")

# %%
df
# Out:
#              artist                   song  \
# 0              ABBA  Ahe's My Kind Of Girl
# 1              ABBA       Andante, Andante
# 2              ABBA         As Good As New
# 3              ABBA                   Bang
# 4              ABBA       Bang-A-Boomerang
# ...             ...                    ...
# 57645  Ziggy Marley          Good Old Days
# 57646  Ziggy Marley          Hand To Mouth
# 57647          Zwan           Come With Me
# 57648          Zwan                 Desire
# 57649          Zwan              Heartsong
#
#                                               link  \
# 0       /a/abba/ahes+my+kind+of+girl_20598417.html
# 1            /a/abba/andante+andante_20002708.html
# 2             /a/abba/as+good+as+new_20003033.html
# 3                       /a/abba/bang_20598415.html
# 4           /a/abba/bang+a+boomerang_20002668.html
# ...                                            ...
# 57645  /z/ziggy+marley/good+old+days_10198588.html
# ...

# %% [markdown]
# ## Content Based Recomandation System

# %%
# %pip install rake_nltk
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 21.3.1; however, version 23.0.1 is available.
# You should consider upgrading via the 'c:\Users\abhay\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.

# %%
import numpy as np
from rake_nltk import Rake
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.feature_extraction.text import CountVectorizer

# %%
df
# Out:
#              artist                   song  \
# 0              ABBA  Ahe's My Kind Of Girl
# 1              ABBA       Andante, Andante
# 2              ABBA         As Good As New
# 3              ABBA                   Bang
# 4              ABBA       Bang-A-Boomerang
# ...             ...                    ...
# 57645  Ziggy Marley          Good Old Days
# 57646  Ziggy Marley          Hand To Mouth
# 57647          Zwan           Come With Me
# 57648          Zwan                 Desire
# 57649          Zwan              Heartsong
#
#                                               link  \
# 0       /a/abba/ahes+my+kind+of+girl_20598417.html
# 1            /a/abba/andante+andante_20002708.html
# 2             /a/abba/as+good+as+new_20003033.html
# 3                       /a/abba/bang_20598415.html
# 4           /a/abba/bang+a+boomerang_20002668.html
# ...                                            ...
# 57645  /z/ziggy+marley/good+old+days_10198588.html
# ...

# %%
import string
for i in range(len(df['text'])):
    df['text'][i] = df['text'][i].translate(str.maketrans('', '', string.punctuation))

df
# Out:
#              artist                   song  \
# 0              ABBA  Ahe's My Kind Of Girl
# 1              ABBA       Andante, Andante
# 2              ABBA         As Good As New
# 3              ABBA                   Bang
# 4              ABBA       Bang-A-Boomerang
# ...             ...                    ...
# 57645  Ziggy Marley          Good Old Days
# 57646  Ziggy Marley          Hand To Mouth
# 57647          Zwan           Come With Me
# 57648          Zwan                 Desire
# 57649          Zwan              Heartsong
#
#                                               link  \
# 0       /a/abba/ahes+my+kind+of+girl_20598417.html
# 1            /a/abba/andante+andante_20002708.html
# 2             /a/abba/as+good+as+new_20003033.html
# 3                       /a/abba/bang_20598415.html
# 4           /a/abba/bang+a+boomerang_20002668.html
# ...                                            ...
# 57645  /z/ziggy+marley/good+old+days_10198588.html
# ...

# %%
df['Key_words'] = ''   # initializing a new column
r = Rake()   # using Rake to remove stop words

# %%
df
# Out:
#              artist                   song  \
# 0              ABBA  Ahe's My Kind Of Girl
# 1              ABBA       Andante, Andante
# 2              ABBA         As Good As New
# 3              ABBA                   Bang
# 4              ABBA       Bang-A-Boomerang
# ...             ...                    ...
# 57645  Ziggy Marley          Good Old Days
# 57646  Ziggy Marley          Hand To Mouth
# 57647          Zwan           Come With Me
# 57648          Zwan                 Desire
# 57649          Zwan              Heartsong
#
#                                               link  \
# 0       /a/abba/ahes+my+kind+of+girl_20598417.html
# 1            /a/abba/andante+andante_20002708.html
# 2             /a/abba/as+good+as+new_20003033.html
# 3                       /a/abba/bang_20598415.html
# 4           /a/abba/bang+a+boomerang_20002668.html
# ...                                            ...
# 57645  /z/ziggy+marley/good+old+days_10198588.html
# ...

# %%
for index, row in df.iterrows():
    r.extract_keywords_from_text(row['text'])   # to extract key words 
    key_words_dict_scores = r.get_word_degrees()    # to get dictionary with key words and their similarity scores
    row['Key_words'] = list(key_words_dict_scores.keys())

# %%
df
# Out:
#              artist                   song  \
# 0              ABBA  Ahe's My Kind Of Girl
# 1              ABBA       Andante, Andante
# 2              ABBA         As Good As New
# 3              ABBA                   Bang
# 4              ABBA       Bang-A-Boomerang
# ...             ...                    ...
# 57645  Ziggy Marley          Good Old Days
# 57646  Ziggy Marley          Hand To Mouth
# 57647          Zwan           Come With Me
# 57648          Zwan                 Desire
# 57649          Zwan              Heartsong
#
#                                               link  \
# 0       /a/abba/ahes+my+kind+of+girl_20598417.html
# 1            /a/abba/andante+andante_20002708.html
# 2             /a/abba/as+good+as+new_20003033.html
# 3                       /a/abba/bang_20598415.html
# 4           /a/abba/bang+a+boomerang_20002668.html
# ...                                            ...
# 57645  /z/ziggy+marley/good+old+days_10198588.html
# ...

# %%
df['artist'] = df['artist'].str.lower()
df
# Out:
#              artist                   song  \
# 0              abba  Ahe's My Kind Of Girl
# 1              abba       Andante, Andante
# 2              abba         As Good As New
# 3              abba                   Bang
# 4              abba       Bang-A-Boomerang
# ...             ...                    ...
# 57645  ziggy marley          Good Old Days
# 57646  ziggy marley          Hand To Mouth
# 57647          zwan           Come With Me
# 57648          zwan                 Desire
# 57649          zwan              Heartsong
#
#                                               link  \
# 0       /a/abba/ahes+my+kind+of+girl_20598417.html
# 1            /a/abba/andante+andante_20002708.html
# 2             /a/abba/as+good+as+new_20003033.html
# 3                       /a/abba/bang_20598415.html
# 4           /a/abba/bang+a+boomerang_20002668.html
# ...                                            ...
# 57645  /z/ziggy+marley/good+old+days_10198588.html
# ...

# %%
df['Bag_of_words'] = ''
# # columns = ['artist','Key_words']

# # df["Bag_of_words"] = df['artist']+" "+ df["Key_words"].astype(str)
# # df["Bag_of_words"] = df[["artist", "Key_words"]].apply(" ".join, axis=1)
temp = " "
for i in range(len(df['text'])):
    temp = ' '.join([str(elem) for elem in df["Key_words"][i]])
    df['Bag_of_words'][i] = df['artist'][i] + " " + temp

# %%
df
# Out:
#              artist                   song  \
# 0              abba  Ahe's My Kind Of Girl
# 1              abba       Andante, Andante
# 2              abba         As Good As New
# 3              abba                   Bang
# 4              abba       Bang-A-Boomerang
# ...             ...                    ...
# 57645  ziggy marley          Good Old Days
# 57646  ziggy marley          Hand To Mouth
# 57647          zwan           Come With Me
# 57648          zwan                 Desire
# 57649          zwan              Heartsong
#
#                                               link  \
# 0       /a/abba/ahes+my+kind+of+girl_20598417.html
# 1            /a/abba/andante+andante_20002708.html
# 2             /a/abba/as+good+as+new_20003033.html
# 3                       /a/abba/bang_20598415.html
# 4           /a/abba/bang+a+boomerang_20002668.html
# ...                                            ...
# 57645  /z/ziggy+marley/good+old+days_10198588.html
# ...

# %%
# df['Bag_of_words'] = df['Bag_of_words'].str.strip().str.replace(' ', ' ').str.replace('  ', ' ')

df_new = df[['song','Bag_of_words']]
df_new
# Out:
#                         song  \
# 0      Ahe's My Kind Of Girl
# 1           Andante, Andante
# 2             As Good As New
# 3                       Bang
# 4           Bang-A-Boomerang
# ...                      ...
# 57645          Good Old Days
# 57646          Hand To Mouth
# 57647           Come With Me
# 57648                 Desire
# 57649              Heartsong
#
#                                             Bag_of_words
# 0      abba look face wonderful means something speci...
# 1      abba take easy please touch gently like summer...
# 2      abba ill never know go put lousy rotten show b...
# 3      abba making somebody happy question give take ...
# 4      abba making somebody happy question give take ...
# ...                                                  ...
# 57645  ziggy marley irie days come play let angels fl...
# 57646  ziggy marley power workers need got free zone ...
# 57647  zwan need something ill believe flashlights ha...
# ...

# %%
df_1 = df_new.iloc[:int(len(df_new)/2),:]
df_2 = df_new.iloc[int(len(df_new)/2):,:]

# %%
df_1
# Out:
#                          song  \
# 0       Ahe's My Kind Of Girl
# 1            Andante, Andante
# 2              As Good As New
# 3                        Bang
# 4            Bang-A-Boomerang
# ...                       ...
# 28820  For Your Precious Love
# 28821                Fraulein
# 28822  Free Born Rambling Man
# 28823     Fuzzy Was An Outlaw
# 28824    Get A Little Dirt On
#
#                                             Bag_of_words
# 0      abba look face wonderful means something speci...
# 1      abba take easy please touch gently like summer...
# 2      abba ill never know go put lousy rotten show b...
# 3      abba making somebody happy question give take ...
# 4      abba making somebody happy question give take ...
# ...                                                  ...
# 28820  david allan coe know first started album thoug...
# 28821  david allan coe far across deep blue waters li...
# 28822  david allan coe never meant leave intentions s...
# ...

# %%
count = CountVectorizer()
count_matrix = count.fit_transform(df_1['Bag_of_words'])
count_matrix
cosine_sim_1 = cosine_similarity(count_matrix, count_matrix)
print(cosine_sim_1)
# Out:
# [[1.         0.06793662 0.13302601 ... 0.08633531 0.04003204 0.09857281]
#  [0.06793662 1.         0.15105264 ... 0.06099943 0.01767767 0.1160762 ]
#  [0.13302601 0.15105264 1.         ... 0.12797396 0.02966954 0.13393735]
#  ...
#  [0.08633531 0.06099943 0.12797396 ... 1.         0.10783277 0.1216975 ]
#  [0.04003204 0.01767767 0.02966954 ... 0.10783277 1.         0.08977311]
#  [0.09857281 0.1160762  0.13393735 ... 0.1216975  0.08977311 1.        ]]

# %%
count = CountVectorizer()
count_matrix = count.fit_transform(df_2['Bag_of_words'])
count_matrix
cosine_sim_2 = cosine_similarity(count_matrix, count_matrix)
print(cosine_sim_2)
# Out:
# [[1.         0.10650585 0.1281237  ... 0.06134623 0.04911438 0.05170109]
#  [0.10650585 1.         0.07055563 ... 0.0743212  0.03966818 0.04175738]
#  [0.1281237  0.07055563 1.         ... 0.05201829 0.         0.07306622]
#  ...
#  [0.06134623 0.0743212  0.05201829 ... 1.         0.09139378 0.11544868]
#  [0.04911438 0.03966818 0.         ... 0.09139378 1.         0.17972366]
#  [0.05170109 0.04175738 0.07306622 ... 0.11544868 0.17972366 1.        ]]

# %%
cosine_sim = np.concatenate((cosine_sim_1,cosine_sim_2))
cosine_sim
# Out:
# array([[1.        , 0.06793662, 0.13302601, ..., 0.08633531, 0.04003204,
#         0.09857281],
#        [0.06793662, 1.        , 0.15105264, ..., 0.06099943, 0.01767767,
#         0.1160762 ],
#        [0.13302601, 0.15105264, 1.        , ..., 0.12797396, 0.02966954,
#         0.13393735],
#        ...,
#        [0.06134623, 0.0743212 , 0.05201829, ..., 1.        , 0.09139378,
#         0.11544868],
#        [0.04911438, 0.03966818, 0.        , ..., 0.09139378, 1.        ,
#         0.17972366],
#        [0.05170109, 0.04175738, 0.07306622, ..., 0.11544868, 0.17972366,
#         1.        ]])

# %%
print(cosine_sim)
# Out:
# [[1.         0.06793662 0.13302601 ... 0.08633531 0.04003204 0.09857281]
#  [0.06793662 1.         0.15105264 ... 0.06099943 0.01767767 0.1160762 ]
#  [0.13302601 0.15105264 1.         ... 0.12797396 0.02966954 0.13393735]
#  ...
#  [0.06134623 0.0743212  0.05201829 ... 1.         0.09139378 0.11544868]
#  [0.04911438 0.03966818 0.         ... 0.09139378 1.         0.17972366]
#  [0.05170109 0.04175738 0.07306622 ... 0.11544868 0.17972366 1.        ]]

# %%
indices = pd.Series(df['song'])

# %%
def recommend(title, cosine_sim = cosine_sim):
    recommended_movies = []
    idx = indices[indices == title].index[0]   # to get the index of the movie title matching the input song
    score_series = pd.Series(cosine_sim[idx]).sort_values(ascending = False)   # similarity scores in descending order
    top_5_indices = list(score_series.iloc[1:6].index)   # to get the indices of top 6 most similar songs
    # [1:6] to exclude 0 (index 0 is the input song itself)
    
    for i in top_5_indices:   # to append the titles of top 10 similar songs to the recommended_movies list
        recommended_movies.append(list(df_new['song'])[i])
        
    return recommended_movies

# %%
recommend('As Good As New')
# Out:
# ['Make Me Happy',
#  'I Will Always Love You',
#  'Give It Up',
#  'I Need Love',
#  "What I'm Looking For"]
